# %%
import requests
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests as r
import time as dt
import sqlalchemy
from datetime import datetime, timedelta

# %%
url = 'https://rest.coinapi.io/v1/quotes/HBDM_PERP_DOGE_USD&HBDM_FTS_BTC_USD_210528/latest'
headers = {'X-CoinAPI-Key' : '64446BC7-8FF8-4090-89CD-5158CCF7D7B6'}
response = requests.get(url, headers=headers).json()
response
# Out:
# [{'symbol_id': 'HBDM_PERP_DOGE_USD',
#   'time_exchange': '2021-05-22T12:23:21.5853922Z',
#   'time_coinapi': '2021-05-22T12:23:21.5853922Z',
#   'ask_price': 0.352171,
#   'ask_size': 530.0,
#   'bid_price': 0.35217,
#   'bid_size': 1750.0},
#  {'symbol_id': 'HBDM_PERP_DOGE_USD',
#   'time_exchange': '2021-05-22T12:23:21.4826925Z',
#   'time_coinapi': '2021-05-22T12:23:21.4826925Z',
#   'ask_price': 0.352171,
#   'ask_size': 530.0,
#   'bid_price': 0.35217,
#   'bid_size': 1347.0},
#  {'symbol_id': 'HBDM_PERP_DOGE_USD',
#   'time_exchange': '2021-05-22T12:23:21.3826583Z',
#   'time_coinapi': '2021-05-22T12:23:21.3826583Z',
#   'ask_price': 0.352171,
#   'ask_size': 530.0,
#   'bid_price': 0.35217,
#   'bid_size': 1016.0},
#  {'symbol_id': 'HBDM_PERP_DOGE_USD',
#   'time_exchange': '2021-05-22T12:23:21.2844983Z',
#   'time_coinapi': '2021-05-22T12:23:21.2844983Z',
#   'ask_price': 0.352171,
#   'ask_size': 1110.0,
#   'bid_price': 0.35217,
#   'bid_size': 757.0},
#  {'symbol_id': 'HBDM_PERP_DOGE_USD',
#   'time_exchange': '2021-05-22T12:23:21.1874516Z',
#   'time_coinapi': '2021-05-22T12:23:21.1874516Z',
#   'ask_price': 0.352171,
#   'ask_size': 1360.0,
#   'bid_price': 0.35217,
#   'bid_size': 758.0},
#  {'symbol_id': 'HBDM_PERP_DOGE_USD',
#   'time_exchange': '2021-05-22T12:23:21.0873123Z',
#   'time_coinapi': '2021-05-22T12:23:21.0873123Z',
#   'ask_price': 0.352171,
#   'ask_size': 1360.0,
#   'bid_price': 0.35217,
#   'bid_size': 757.0},
#  {'symbol_id': 'HBDM_PERP_DOGE_USD',
#   'time_exchange': '2021-05-22T12:23:20.9828039Z',
#   'time_coinapi': '2021-05-22T12:23:20.9828039Z',
#   'ask_price': 0.352171,
#   'ask_size': 1360.0,
#   'bid_price': 0.35217,
#   'bid_size': 1243.0},
#  {'symbol_id': 'HBDM_PERP_DOGE_USD',
#   'time_exchange': '2021-05-22T12:23:20.8817327Z',
#   'time_coinapi': '2021-05-22T12:23:20.8817327Z',
#   'ask_price': 0.352171,
#   'ask_size': 1610.0,
#   'bid_price': 0.35217,
#   'bid_size': 757.0},
#  {'symbol_id': 'HBDM_PERP_DOGE_USD',
#   'time_exchange': '2021-05-22T12:23:20.7855040Z',
#   'time_coinapi': '2021-05-22T12:23:20.7855040Z',
#   'ask_price': 0.352171,
#   'ask_size': 1847.0,
#   'bid_price': 0.35217,
#   'bid_size': 507.0},
#  {'symbol_id': 'HBDM_PERP_DOGE_USD',
#   'time_exchange': '2021-05-21T22:05:46.0919119Z',
#   'time_coinapi': '2021-05-21T22:05:46.0919119Z',
#   'ask_price': 0.350427,
#   'ask_size': 549.0,
#   'bid_price': 0.350426,
#   'bid_size': 10.0},
#  {'symbol_id': 'HBDM_PERP_DOGE_USD',
#   'time_exchange': '2021-05-21T22:05:45.9909066Z',
#   'time_coinapi': '2021-05-21T22:05:45.9909066Z',
#   'ask_price': 0.350505,
#   'ask_size': 249.0,
#   'bid_price': 0.350426,
#   'bid_size': 50.0},
#  {'symbol_id': 'HBDM_PERP_DOGE_USD',
#   'time_exchange': '2021-05-21T22:05:45.9164909Z',
#   'time_coinapi': '2021-05-21T22:05:45.9164909Z',
#   'ask_price': 0.350513,
#   'ask_size': 553.0,
#   'bid_price': 0.350512,
#   'bid_size': 929.0},
#  {'symbol_id': 'HBDM_PERP_DOGE_USD',
#   'time_exchange': '2021-05-21T22:05:45.6918607Z',
#   'time_coinapi': '2021-05-21T22:05:45.6918607Z',
#   'ask_price': 0.350513,
#   'ask_size': 53.0,
#   'bid_price': 0.350512,
#   'bid_size': 1179.0},
#  {'symbol_id': 'HBDM_PERP_DOGE_USD',
#   'time_exchange': '2021-05-21T22:05:45.4830811Z',
#   'time_coinapi': '2021-05-21T22:05:45.4830811Z',
#   'ask_price': 0.350513,
#   'ask_size': 53.0,
#   'bid_price': 0.350512,
#   'bid_size': 2071.0},
#  {'symbol_id': 'HBDM_PERP_DOGE_USD',
#   'time_exchange': '2021-05-21T22:05:45.4828886Z',
#   'time_coinapi': '2021-05-21T22:05:45.4828886Z',
#   'ask_price': 0.350513,
#   'ask_size': 53.0,
#   'bid_price': 0.350512,
#   'bid_size': 2070.0},
#  {'symbol_id': 'HBDM_PERP_DOGE_USD',
#   'time_exchange': '2021-05-21T22:05:45.1735352Z',
#   'time_coinapi': '2021-05-21T22:05:45.1735352Z',
#   'ask_price': 0.350513,
#   'ask_size': 53.0,
#   'bid_price': 0.350512,
#   'bid_size': 2071.0},
#  {'symbol_id': 'HBDM_PERP_DOGE_USD',
#   'time_exchange': '2021-05-21T22:05:45.1554854Z',
#   'time_coinapi': '2021-05-21T22:05:45.1554854Z',
#   'ask_price': 0.350513,
#   'ask_size': 53.0,
#   'bid_price': 0.350512,
#   'bid_size': 2070.0},
#  {'symbol_id': 'HBDM_PERP_DOGE_USD',
#   'time_exchange': '2021-05-21T22:05:45.1545107Z',
#   'time_coinapi': '2021-05-21T22:05:45.1545107Z',
#   'ask_price': 0.350513,
#   'ask_size': 53.0,
#   'bid_price': 0.350512,
#   'bid_size': 2040.0},
#  {'symbol_id': 'HBDM_PERP_DOGE_USD',
#   'time_exchange': '2021-05-21T22:05:45.1544678Z',
#   'time_coinapi': '2021-05-21T22:05:45.1544678Z',
#   'ask_price': 0.350513,
#   'ask_size': 53.0,
#   'bid_price': 0.350512,
#   'bid_size': 2018.0},
#  {'symbol_id': 'HBDM_PERP_DOGE_USD',
#   'time_exchange': '2021-05-21T22:05:44.8323471Z',
#   'time_coinapi': '2021-05-21T22:05:44.8323471Z',
#   'ask_price': 0.350513,
#   'ask_size': 70.0,
#   'bid_price': 0.350512,
#   'bid_size': 2018.0},
#  {'symbol_id': 'HBDM_PERP_DOGE_USD',
#   'time_exchange': '2021-05-21T22:05:44.8310884Z',
#   'time_coinapi': '2021-05-21T22:05:44.8310884Z',
#   'ask_price': 0.350513,
#   'ask_size': 70.0,
#   'bid_price': 0.350512,
#   'bid_size': 2017.0},
#  {'symbol_id': 'HBDM_PERP_DOGE_USD',
#   'time_exchange': '2021-05-21T22:05:44.8204210Z',
#   'time_coinapi': '2021-05-21T22:05:44.8204210Z',
#   'ask_price': 0.350513,
#   'ask_size': 70.0,
#   'bid_price': 0.350512,
#   'bid_size': 2018.0},
#  {'symbol_id': 'HBDM_PERP_DOGE_USD',
#   'time_exchange': '2021-05-21T22:05:44.5267173Z',
#   'time_coinapi': '2021-05-21T22:05:44.5267173Z',
#   'ask_price': 0.350513,
#   'ask_size': 70.0,
#   'bid_price': 0.350512,
#   'bid_size': 1178.0},
#  {'symbol_id': 'HBDM_PERP_DOGE_USD',
#   'time_exchange': '2021-05-21T22:05:44.5266581Z',
#   'time_coinapi': '2021-05-21T22:05:44.5266581Z',
#   'ask_price': 0.350513,
#   'ask_size': 70.0,
#   'bid_price': 0.350512,
#   'bid_size': 1179.0},
#  {'symbol_id': 'HBDM_PERP_DOGE_USD',
#   'time_exchange': '2021-05-21T22:05:42.3664490Z',
#   'time_coinapi': '2021-05-21T22:05:42.3664490Z',
#   'ask_price': 0.350685,
#   'ask_size': 704.0,
#   'bid_price': 0.350513,
#   'bid_size': 110.0},
#  {'symbol_id': 'HBDM_PERP_DOGE_USD',
#   'time_exchange': '2021-05-21T22:05:42.2772345Z',
#   'time_coinapi': '2021-05-21T22:05:42.2772345Z',
#   'ask_price': 0.350694,
#   'ask_size': 69.0,
#   'bid_price': 0.350513,
#   'bid_size': 110.0},
#  {'symbol_id': 'HBDM_PERP_DOGE_USD',
#   'time_exchange': '2021-05-21T22:05:42.1666506Z',
#   'time_coinapi': '2021-05-21T22:05:42.1666506Z',
#   'ask_price': 0.350695,
#   'ask_size': 1646.0,
#   'bid_price': 0.350513,
#   'bid_size': 110.0},
#  {'symbol_id': 'HBDM_PERP_DOGE_USD',
#   'time_exchange': '2021-05-21T22:05:42.0675318Z',
#   'time_coinapi': '2021-05-21T22:05:42.0675318Z',
#   'ask_price': 0.350704,
#   'ask_size': 110.0,
#   'bid_price': 0.350522,
#   'bid_size': 110.0},
#  {'symbol_id': 'HBDM_PERP_DOGE_USD',
#   'time_exchange': '2021-05-21T22:05:41.9652485Z',
#   'time_coinapi': '2021-05-21T22:05:41.9652485Z',
#   'ask_price': 0.350714,
#   'ask_size': 84.0,
#   'bid_price': 0.350633,
#   'bid_size': 60.0},
#  {'symbol_id': 'HBDM_PERP_DOGE_USD',
#   'time_exchange': '2021-05-21T22:05:41.6647259Z',
#   'time_coinapi': '2021-05-21T22:05:41.6647259Z',
#   'ask_price': 0.350714,
#   'ask_size': 84.0,
#   'bid_price': 0.350633,
#   'bid_size': 110.0},
#  {'symbol_id': 'HBDM_PERP_DOGE_USD',
#   'time_exchange': '2021-05-21T22:05:41.4653328Z',
#   'time_coinapi': '2021-05-21T22:05:41.4653328Z',
#   'ask_price': 0.350714,
#   'ask_size': 294.0,
#   'bid_price': 0.350682,
#   'bid_size': 110.0},
#  {'symbol_id': 'HBDM_PERP_DOGE_USD',
#   'time_exchange': '2021-05-21T22:05:41.3976013Z',
#   'time_coinapi': '2021-05-21T22:05:41.3976013Z',
#   'ask_price': 0.350715,
#   'ask_size': 702.0,
#   'bid_price': 0.350678,
#   'bid_size': 49.0},
#  {'symbol_id': 'HBDM_PERP_DOGE_USD',
#   'time_exchange': '2021-05-21T22:05:41.2681896Z',
#   'time_coinapi': '2021-05-21T22:05:41.2681896Z',
#   'ask_price': 0.350617,
#   'ask_size': 110.0,
#   'bid_price': 0.350555,
#   'bid_size': 1.0},
#  {'symbol_id': 'HBDM_PERP_DOGE_USD',
#   'time_exchange': '2021-05-21T22:05:41.1676638Z',
#   'time_coinapi': '2021-05-21T22:05:41.1676638Z',
#   'ask_price': 0.350617,
#   'ask_size': 110.0,
#   'bid_price': 0.350515,
#   'bid_size': 1.0},
#  {'symbol_id': 'HBDM_PERP_DOGE_USD',
#   'time_exchange': '2021-05-21T22:05:40.9650641Z',
#   'time_coinapi': '2021-05-21T22:05:40.9650641Z',
#   'ask_price': 0.350615,
#   'ask_size': 110.0,
#   'bid_price': 0.350506,
#   'bid_size': 2.0},
#  {'symbol_id': 'HBDM_PERP_DOGE_USD',
#   'time_exchange': '2021-05-21T22:05:40.8655559Z',
#   'time_coinapi': '2021-05-21T22:05:40.8655559Z',
#   'ask_price': 0.350623,
#   'ask_size': 482.0,
#   'bid_price': 0.350506,
#   'bid_size': 2.0},
#  {'symbol_id': 'HBDM_PERP_DOGE_USD',
#   'time_exchange': '2021-05-21T22:05:40.7667016Z',
#   'time_coinapi': '2021-05-21T22:05:40.7667016Z',
#   'ask_price': 0.350624,
#   'ask_size': 110.0,
#   'bid_price': 0.350506,
#   'bid_size': 2.0},
#  {'symbol_id': 'HBDM_PERP_DOGE_USD',
#   'time_exchange': '2021-05-21T22:05:40.6641944Z',
#   'time_coinapi': '2021-05-21T22:05:40.6641944Z',
#   'ask_price': 0.350506,
#   'ask_size': 18.0,
#   'bid_price': 0.350505,
#   'bid_size': 252.0},
#  {'symbol_id': 'HBDM_PERP_DOGE_USD',
#   'time_exchange': '2021-05-21T22:05:40.5657030Z',
#   'time_coinapi': '2021-05-21T22:05:40.5657030Z',
#   'ask_price': 0.350506,
#   'ask_size': 98.0,
#   'bid_price': 0.350505,
#   'bid_size': 253.0},
#  {'symbol_id': 'HBDM_PERP_DOGE_USD',
#   'time_exchange': '2021-05-21T22:05:40.4682163Z',
#   'time_coinapi': '2021-05-21T22:05:40.4682163Z',
#   'ask_price': 0.350627,
#   'ask_size': 736.0,
#   'bid_price': 0.350506,
#   'bid_size': 2.0},
#  {'symbol_id': 'HBDM_PERP_DOGE_USD',
#   'time_exchange': '2021-05-21T22:05:40.3650524Z',
#   'time_coinapi': '2021-05-21T22:05:40.3650524Z',
#   'ask_price': 0.350627,
#   'ask_size': 796.0,
#   'bid_price': 0.350506,
#   'bid_size': 1150.0},
#  {'symbol_id': 'HBDM_PERP_DOGE_USD',
#   'time_exchange': '2021-05-21T22:05:40.2661202Z',
#   'time_coinapi': '2021-05-21T22:05:40.2661202Z',
#   'ask_price': 0.350636,
#   'ask_size': 100.0,
#   'bid_price': 0.350506,
#   'bid_size': 1150.0},
#  {'symbol_id': 'HBDM_PERP_DOGE_USD',
#   'time_exchange': '2021-05-21T22:05:39.7647508Z',
#   'time_coinapi': '2021-05-21T22:05:39.7647508Z',
#   'ask_price': 0.350506,
#   'ask_size': 273.0,
#   'bid_price': 0.350505,
#   'bid_size': 251.0},
#  {'symbol_id': 'HBDM_PERP_DOGE_USD',
#   'time_exchange': '2021-05-21T22:05:39.6649319Z',
#   'time_coinapi': '2021-05-21T22:05:39.6649319Z',
#   'ask_price': 0.350506,
#   'ask_size': 273.0,
#   'bid_price': 0.350505,
#   'bid_size': 59.0},
#  {'symbol_id': 'HBDM_PERP_DOGE_USD',
#   'time_exchange': '2021-05-21T22:05:39.1649687Z',
#   'time_coinapi': '2021-05-21T22:05:39.1649687Z',
#   'ask_price': 0.350506,
#   'ask_size': 273.0,
#   'bid_price': 0.350505,
#   'bid_size': 709.0},
#  {'symbol_id': 'HBDM_PERP_DOGE_USD',
#   'time_exchange': '2021-05-21T22:05:38.6675643Z',
#   'time_coinapi': '2021-05-21T22:05:38.6675643Z',
#   'ask_price': 0.350506,
#   'ask_size': 23.0,
#   'bid_price': 0.350505,
#   'bid_size': 709.0},
#  {'symbol_id': 'HBDM_PERP_DOGE_USD',
#   'time_exchange': '2021-05-21T22:05:38.4681595Z',
#   'time_coinapi': '2021-05-21T22:05:38.4681595Z',
#   'ask_price': 0.350506,
#   'ask_size': 23.0,
#   'bid_price': 0.350505,
#   'bid_size': 1729.0},
#  {'symbol_id': 'HBDM_PERP_DOGE_USD',
#   'time_exchange': '2021-05-21T22:05:38.3724203Z',
#   'time_coinapi': '2021-05-21T22:05:38.3724203Z',
#   'ask_price': 0.350506,
#   'ask_size': 23.0,
#   'bid_price': 0.350505,
#   'bid_size': 709.0},
#  {'symbol_id': 'HBDM_PERP_DOGE_USD',
#   'time_exchange': '2021-05-21T22:05:38.1653634Z',
#   'time_coinapi': '2021-05-21T22:05:38.1653634Z',
#   'ask_price': 0.350506,
#   'ask_size': 23.0,
#   'bid_price': 0.350505,
#   'bid_size': 1595.0},
#  {'symbol_id': 'HBDM_PERP_DOGE_USD',
#   'time_exchange': '2021-05-21T22:05:37.6653540Z',
#   'time_coinapi': '2021-05-21T22:05:37.6653540Z',
#   'ask_price': 0.350506,
#   'ask_size': 23.0,
#   'bid_price': 0.350505,
#   'bid_size': 709.0},
#  {'symbol_id': 'HBDM_PERP_DOGE_USD',
#   'time_exchange': '2021-05-21T22:05:37.5657613Z',
#   'time_coinapi': '2021-05-21T22:05:37.5657613Z',
#   'ask_price': 0.350506,
#   'ask_size': 23.0,
#   'bid_price': 0.350505,
#   'bid_size': 708.0},
#  {'symbol_id': 'HBDM_PERP_DOGE_USD',
#   'time_exchange': '2021-05-21T22:05:37.5113437Z',
#   'time_coinapi': '2021-05-21T22:05:37.5113437Z',
#   'ask_price': 0.350506,
#   'ask_size': 34.0,
#   'bid_price': 0.350505,
#   'bid_size': 708.0},
#  {'symbol_id': 'HBDM_PERP_DOGE_USD',
#   'time_exchange': '2021-05-21T22:05:37.3674614Z',
#   'time_coinapi': '2021-05-21T22:05:37.3674614Z',
#   'ask_price': 0.350506,
#   'ask_size': 34.0,
#   'bid_price': 0.350505,
#   'bid_size': 1479.0},
#  {'symbol_id': 'HBDM_PERP_DOGE_USD',
#   'time_exchange': '2021-05-21T22:05:37.2660105Z',
#   'time_coinapi': '2021-05-21T22:05:37.2660105Z',
#   'ask_price': 0.350506,
#   'ask_size': 77.0,
#   'bid_price': 0.350505,
#   'bid_size': 98.0},
#  {'symbol_id': 'HBDM_PERP_DOGE_USD',
#   'time_exchange': '2021-05-21T22:05:37.1673366Z',
#   'time_coinapi': '2021-05-21T22:05:37.1673366Z',
#   'ask_price': 0.350482,
#   'ask_size': 57.0,
#   'bid_price': 0.350481,
#   'bid_size': 251.0},
#  {'symbol_id': 'HBDM_PERP_DOGE_USD',
#   'time_exchange': '2021-05-21T22:05:37.1658536Z',
#   'time_coinapi': '2021-05-21T22:05:37.1658536Z',
#   'ask_price': 0.350482,
#   'ask_size': 57.0,
#   'bid_price': 0.350481,
#   'bid_size': 1.0},
#  {'symbol_id': 'HBDM_PERP_DOGE_USD',
#   'time_exchange': '2021-05-21T22:05:37.0669378Z',
#   'time_coinapi': '2021-05-21T22:05:37.0669378Z',
#   'ask_price': 0.350482,
#   'ask_size': 57.0,
#   'bid_price': 0.350465,
#   'bid_size': 110.0},
#  {'symbol_id': 'HBDM_PERP_DOGE_USD',
#   'time_exchange': '2021-05-21T22:05:36.9667966Z',
#   'time_coinapi': '2021-05-21T22:05:36.9667966Z',
#   'ask_price': 0.350506,
#   'ask_size': 425.0,
#   'bid_price': 0.350457,
#   'bid_size': 156.0},
#  {'symbol_id': 'HBDM_PERP_DOGE_USD',
#   'time_exchange': '2021-05-21T22:05:36.8893584Z',
#   'time_coinapi': '2021-05-21T22:05:36.8893584Z',
#   'ask_price': 0.350506,
#   'ask_size': 425.0,
#   'bid_price': 0.350505,
#   'bid_size': 360.0},
#  {'symbol_id': 'HBDM_PERP_DOGE_USD',
#   'time_exchange': '2021-05-21T22:05:36.7649035Z',
#   'time_coinapi': '2021-05-21T22:05:36.7649035Z',
#   'ask_price': 0.350506,
#   'ask_size': 348.0,
#   'bid_price': 0.350505,
#   'bid_size': 360.0},
#  {'symbol_id': 'HBDM_PERP_DOGE_USD',
#   'time_exchange': '2021-05-21T22:05:36.6656593Z',
#   'time_coinapi': '2021-05-21T22:05:36.6656593Z',
#   'ask_price': 0.350506,
#   'ask_size': 98.0,
#   'bid_price': 0.350505,
#   'bid_size': 353.0},
#  {'symbol_id': 'HBDM_PERP_DOGE_USD',
#   'time_exchange': '2021-05-21T22:05:36.5653311Z',
#   'time_coinapi': '2021-05-21T22:05:36.5653311Z',
#   'ask_price': 0.350644,
#   'ask_size': 208.0,
#   'bid_price': 0.350539,
#   'bid_size': 110.0},
#  {'symbol_id': 'HBDM_PERP_DOGE_USD',
#   'time_exchange': '2021-05-21T22:05:36.5240195Z',
#   'time_coinapi': '2021-05-21T22:05:36.5240195Z',
#   'ask_price': 0.350644,
#   'ask_size': 208.0,
#   'bid_price': 0.350588,
#   'bid_size': 110.0},
#  {'symbol_id': 'HBDM_PERP_DOGE_USD',
#   'time_exchange': '2021-05-21T22:05:36.5240051Z',
#   'time_coinapi': '2021-05-21T22:05:36.5240051Z',
#   'ask_price': 0.350644,
#   'ask_size': 208.0,
#   'bid_price': 0.350431,
#   'bid_size': 1435.0},
#  {'symbol_id': 'HBDM_PERP_DOGE_USD',
#   'time_exchange': '2021-05-21T22:05:36.3672077Z',
#   'time_coinapi': '2021-05-21T22:05:36.3672077Z',
#   'ask_price': 0.350879,
#   'ask_size': 133.0,
#   'bid_price': 0.350644,
#   'bid_size': 700.0},
#  {'symbol_id': 'HBDM_PERP_DOGE_USD',
#   'time_exchange': '2021-05-21T22:05:36.2654042Z',
#   'time_coinapi': '2021-05-21T22:05:36.2654042Z',
#   'ask_price': 0.350893,
#   'ask_size': 110.0,
#   'bid_price': 0.350698,
#   'bid_size': 110.0},
#  {'symbol_id': 'HBDM_PERP_DOGE_USD',
#   'time_exchange': '2021-05-21T22:05:36.1650395Z',
#   'time_coinapi': '2021-05-21T22:05:36.1650395Z',
#   'ask_price': 0.350911,
#   'ask_size': 38.0,
#   'bid_price': 0.35069,
#   'bid_size': 111.0},
#  {'symbol_id': 'HBDM_PERP_DOGE_USD',
#   'time_exchange': '2021-05-21T22:05:35.9651921Z',
#   'time_coinapi': '2021-05-21T22:05:35.9651921Z',
#   'ask_price': 0.350912,
#   'ask_size': 3604.0,
#   'bid_price': 0.350911,
#   'bid_size': 250.0},
#  {'symbol_id': 'HBDM_PERP_DOGE_USD',
#   'time_exchange': '2021-05-21T22:05:35.8667625Z',
#   'time_coinapi': '2021-05-21T22:05:35.8667625Z',
#   'ask_price': 0.350912,
#   'ask_size': 3580.0,
#   'bid_price': 0.350911,
#   'bid_size': 250.0},
#  {'symbol_id': 'HBDM_PERP_DOGE_USD',
#   'time_exchange': '2021-05-21T22:05:35.7668930Z',
#   'time_coinapi': '2021-05-21T22:05:35.7668930Z',
#   'ask_price': 0.350912,
#   'ask_size': 2566.0,
#   'bid_price': 0.350911,
#   'bid_size': 250.0},
#  {'symbol_id': 'HBDM_PERP_DOGE_USD',
#   'time_exchange': '2021-05-21T22:05:35.6692574Z',
#   'time_coinapi': '2021-05-21T22:05:35.6692574Z',
#   'ask_price': 0.350912,
#   'ask_size': 1030.0,
#   'bid_price': 0.350911,
#   'bid_size': 250.0},
#  {'symbol_id': 'HBDM_PERP_DOGE_USD',
#   'time_exchange': '2021-05-21T22:05:35.4670219Z',
#   'time_coinapi': '2021-05-21T22:05:35.4670219Z',
#   'ask_price': 0.350912,
#   'ask_size': 897.0,
#   'bid_price': 0.350911,
#   'bid_size': 250.0},
#  {'symbol_id': 'HBDM_PERP_DOGE_USD',
#   'time_exchange': '2021-05-21T22:05:35.3696766Z',
#   'time_coinapi': '2021-05-21T22:05:35.3696766Z',
#   'ask_price': 0.350912,
#   'ask_size': 143.0,
#   'bid_price': 0.350911,
#   'bid_size': 250.0},
#  {'symbol_id': 'HBDM_PERP_DOGE_USD',
#   'time_exchange': '2021-05-21T22:05:35.2676421Z',
#   'time_coinapi': '2021-05-21T22:05:35.2676421Z',
#   'ask_price': 0.350912,
#   'ask_size': 243.0,
#   'bid_price': 0.350911,
#   'bid_size': 250.0},
#  {'symbol_id': 'HBDM_PERP_DOGE_USD',
#   'time_exchange': '2021-05-21T22:05:35.1646108Z',
#   'time_coinapi': '2021-05-21T22:05:35.1646108Z',
#   'ask_price': 0.350912,
#   'ask_size': 953.0,
#   'bid_price': 0.350911,
#   'bid_size': 250.0},
#  {'symbol_id': 'HBDM_PERP_DOGE_USD',
#   'time_exchange': '2021-05-21T22:05:35.0670370Z',
#   'time_coinapi': '2021-05-21T22:05:35.0670370Z',
#   'ask_price': 0.350912,
#   'ask_size': 810.0,
#   'bid_price': 0.350911,
#   'bid_size': 250.0},
#  {'symbol_id': 'HBDM_PERP_DOGE_USD',
#   'time_exchange': '2021-05-21T22:05:34.8696046Z',
#   'time_coinapi': '2021-05-21T22:05:34.8696046Z',
#   'ask_price': 0.350912,
#   'ask_size': 100.0,
#   'bid_price': 0.350911,
#   'bid_size': 250.0},
#  {'symbol_id': 'HBDM_PERP_DOGE_USD',
#   'time_exchange': '2021-05-21T22:05:34.7677429Z',
#   'time_coinapi': '2021-05-21T22:05:34.7677429Z',
#   'ask_price': 0.350912,
#   'ask_size': 100.0,
#   'bid_price': 0.350908,
#   'bid_size': 61.0},
#  {'symbol_id': 'HBDM_PERP_DOGE_USD',
#   'time_exchange': '2021-05-21T22:05:34.6746498Z',
#   'time_coinapi': '2021-05-21T22:05:34.6746498Z',
#   'ask_price': 0.350908,
#   'ask_size': 349.0,
#   'bid_price': 0.350907,
#   'bid_size': 49.0},
#  {'symbol_id': 'HBDM_PERP_DOGE_USD',
#   'time_exchange': '2021-05-21T22:05:34.5687614Z',
#   'time_coinapi': '2021-05-21T22:05:34.5687614Z',
#   'ask_price': 0.350894,
#   'ask_size': 2.0,
#   'bid_price': 0.350761,
#   'bid_size': 2.0},
#  {'symbol_id': 'HBDM_PERP_DOGE_USD',
#   'time_exchange': '2021-05-21T22:05:34.4661323Z',
#   'time_coinapi': '2021-05-21T22:05:34.4661323Z',
#   'ask_price': 0.350908,
#   'ask_size': 349.0,
#   'bid_price': 0.35076,
#   'bid_size': 110.0},
#  {'symbol_id': 'HBDM_PERP_DOGE_USD',
#   'time_exchange': '2021-05-21T22:05:34.3665142Z',
#   'time_coinapi': '2021-05-21T22:05:34.3665142Z',
#   'ask_price': 0.350922,
#   'ask_size': 988.0,
#   'bid_price': 0.350735,
#   'bid_size': 110.0},
#  {'symbol_id': 'HBDM_PERP_DOGE_USD',
#   'time_exchange': '2021-05-21T22:05:34.2656967Z',
#   'time_coinapi': '2021-05-21T22:05:34.2656967Z',
#   'ask_price': 0.350792,
#   'ask_size': 110.0,
#   'bid_price': 0.350727,
#   'bid_size': 49.0},
#  {'symbol_id': 'HBDM_PERP_DOGE_USD',
#   'time_exchange': '2021-05-21T22:05:34.1657947Z',
#   'time_coinapi': '2021-05-21T22:05:34.1657947Z',
#   'ask_price': 0.350614,
#   'ask_size': 3.0,
#   'bid_price': 0.350613,
#   'bid_size': 251.0},
#  {'symbol_id': 'HBDM_PERP_DOGE_USD',
#   'time_exchange': '2021-05-21T22:05:34.0663737Z',
#   'time_coinapi': '2021-05-21T22:05:34.0663737Z',
#   'ask_price': 0.350614,
#   'ask_size': 3.0,
#   'bid_price': 0.350451,
#   'bid_size': 68.0},
#  {'symbol_id': 'HBDM_PERP_DOGE_USD',
#   'time_exchange': '2021-05-21T22:05:34.0004743Z',
#   'time_coinapi': '2021-05-21T22:05:34.0004743Z',
#   'ask_price': 0.350555,
#   'ask_size': 2.0,
#   'bid_price': 0.350443,
#   'bid_size': 100.0},
#  {'symbol_id': 'HBDM_PERP_DOGE_USD',
#   'time_exchange': '2021-05-21T22:05:33.8951338Z',
#   'time_coinapi': '2021-05-21T22:05:33.8951338Z',
#   'ask_price': 0.350491,
#   'ask_size': 1.0,
#   'bid_price': 0.350434,
#   'bid_size': 110.0},
#  {'symbol_id': 'HBDM_PERP_DOGE_USD',
#   'time_exchange': '2021-05-21T22:05:33.7738666Z',
#   'time_coinapi': '2021-05-21T22:05:33.7738666Z',
#   'ask_price': 0.350548,
#   'ask_size': 110.0,
#   'bid_price': 0.350434,
#   'bid_size': 110.0},
#  {'symbol_id': 'HBDM_PERP_DOGE_USD',
#   'time_exchange': '2021-05-21T22:05:33.6665152Z',
#   'time_coinapi': '2021-05-21T22:05:33.6665152Z',
#   'ask_price': 0.350546,
#   'ask_size': 2.0,
#   'bid_price': 0.350434,
#   'bid_size': 110.0},
#  {'symbol_id': 'HBDM_PERP_DOGE_USD',
#   'time_exchange': '2021-05-21T22:05:33.3669579Z',
#   'time_coinapi': '2021-05-21T22:05:33.3669579Z',
#   'ask_price': 0.350548,
#   'ask_size': 110.0,
#   'bid_price': 0.350434,
#   'bid_size': 110.0},
#  {'symbol_id': 'HBDM_PERP_DOGE_USD',
#   'time_exchange': '2021-05-21T22:05:33.2669284Z',
#   'time_coinapi': '2021-05-21T22:05:33.2669284Z',
#   'ask_price': 0.350556,
#   'ask_size': 1.0,
#   'bid_price': 0.350434,
#   'bid_size': 110.0},
#  {'symbol_id': 'HBDM_PERP_DOGE_USD',
#   'time_exchange': '2021-05-21T22:05:33.1653717Z',
#   'time_coinapi': '2021-05-21T22:05:33.1653717Z',
#   'ask_price': 0.350623,
#   'ask_size': 55.0,
#   'bid_price': 0.350434,
#   'bid_size': 110.0},
#  {'symbol_id': 'HBDM_PERP_DOGE_USD',
#   'time_exchange': '2021-05-21T22:05:33.1164456Z',
#   'time_coinapi': '2021-05-21T22:05:33.1164456Z',
#   'ask_price': 0.350686,
#   'ask_size': 2.0,
#   'bid_price': 0.350426,
#   'bid_size': 50.0},
#  {'symbol_id': 'HBDM_PERP_DOGE_USD',
#   'time_exchange': '2021-05-21T22:05:32.9692077Z',
#   'time_coinapi': '2021-05-21T22:05:32.9692077Z',
#   'ask_price': 0.350687,
#   'ask_size': 110.0,
#   'bid_price': 0.350443,
#   'bid_size': 110.0},
#  {'symbol_id': 'HBDM_PERP_DOGE_USD',
#   'time_exchange': '2021-05-21T22:05:32.9643665Z',
#   'time_coinapi': '2021-05-21T22:05:32.9643665Z',
#   'ask_price': 0.350687,
#   'ask_size': 110.0,
#   'bid_price': 0.350435,
#   'bid_size': 4.0},
#  {'symbol_id': 'HBDM_PERP_DOGE_USD',
#   'time_exchange': '2021-05-21T22:05:32.8665155Z',
#   'time_coinapi': '2021-05-21T22:05:32.8665155Z',
#   'ask_price': 0.350708,
#   'ask_size': 110.0,
#   'bid_price': 0.350434,
#   'bid_size': 110.0},
#  {'symbol_id': 'HBDM_PERP_DOGE_USD',
#   'time_exchange': '2021-05-21T22:05:32.7668653Z',
#   'time_coinapi': '2021-05-21T22:05:32.7668653Z',
#   'ask_price': 0.350708,
#   'ask_size': 110.0,
#   'bid_price': 0.350549,
#   'bid_size': 2.0},
#  {'symbol_id': 'HBDM_PERP_DOGE_USD',
#   'time_exchange': '2021-05-21T22:05:32.6658570Z',
#   'time_coinapi': '2021-05-21T22:05:32.6658570Z',
#   'ask_price': 0.350716,
#   'ask_size': 1.0,
#   'bid_price': 0.350675,
#   'bid_size': 100.0},
#  {'symbol_id': 'HBDM_PERP_DOGE_USD',
#   'time_exchange': '2021-05-21T22:05:32.5656905Z',
#   'time_coinapi': '2021-05-21T22:05:32.5656905Z',
#   'ask_price': 0.350756,
#   'ask_size': 110.0,
#   'bid_price': 0.350675,
#   'bid_size': 100.0},
#  {'symbol_id': 'HBDM_PERP_DOGE_USD',
#   'time_exchange': '2021-05-21T22:05:32.4656866Z',
#   'time_coinapi': '2021-05-21T22:05:32.4656866Z',
#   'ask_price': 0.350755,
#   'ask_size': 1536.0,
#   'bid_price': 0.350675,
#   'bid_size': 100.0}]

# %%
data_df=pd.DataFrame(response)
data_df
# Out:
#                              symbol_id                 time_exchange  \
# 0   DERIBIT_OPT_BTC_USD_210730_30000_P  2021-05-22T15:09:36.2269689Z
# 1   DERIBIT_OPT_BTC_USD_210523_37000_P  2021-05-22T15:09:36.2240520Z
# 2   DERIBIT_OPT_BTC_USD_210523_33000_P  2021-05-22T15:09:36.2239571Z
# 3   DERIBIT_OPT_BTC_USD_220325_40000_P  2021-05-22T15:09:36.2182899Z
# 4   DERIBIT_OPT_BTC_USD_210604_40000_P  2021-05-22T15:09:36.2182775Z
# ..                                 ...                           ...
# 95            CURRENCYCOM_SPOT_BCH_BTC  2021-05-22T15:09:36.1000000Z
# 96                  BTSE_SPOT_LINK_PAX  2021-05-22T15:09:36.0970327Z
# 97                BITMAX_SPOT_SRM_USDT  2021-05-22T15:09:36.0970000Z
# 98              DRAGONEX_SPOT_BTC2S_DC  2021-05-22T15:09:36.0930418Z
# 99                QUOINE_SPOT_BTC_GYEN  2021-05-22T15:09:36.0912223Z
#
#                     time_coinapi     ask_price  ask_size     bid_price  \
# 0   2021-05-22T15:09:36.2276952Z  1.140000e-01   12.7000  1.100000e-01
# 1   2021-05-22T15:09:36.2278205Z  2.500000e-02   25.8000  2.250000e-02
# 2   2021-05-22T15:09:36.2258243Z  6.500000e-03   29.1000  5.000000e-03
# 3   2021-05-22T15:09:36.2279978Z  3.895000e-01    2.0000  3.670000e-01
# 4   2021-05-22T15:09:36.2267464Z  1.940000e-01    0.4000  1.290000e-01
# ..                           ...           ...       ...           ...
# 95  2021-05-22T15:09:36.1620720Z  1.763000e-02   30.0000  1.752000e-02
# 96  2021-05-22T15:09:36.0973687Z  2.442000e+01  210.8600  2.431300e+01
# 97  2021-05-22T15:09:36.2570125Z  4.971650e+00   37.0000  4.954480e+00
# 98  2021-05-22T15:09:36.0931628Z  1.057160e+00   20.0000  9.394400e-01
# 99  2021-05-22T15:09:36.0912223Z  4.094518e+06    0.0119  4.075669e+06
#
#     bid_size
# 0      25.20
# 1      17.70
# 2      17.00
# 3       4.00
# 4      15.00
# ..       ...
# 95     30.00
# 96    144.06
# 97     69.00
# 98     20.00
# 99      0.05
#
# [100 rows x 7 columns]

# %%
doge_df = data_df[data_df['symbol_id'] == 'HBDM_PERP_DOGE_USD'] 
doge_df
# Out:
# Empty DataFrame
# Columns: [symbol_id, time_exchange, time_coinapi, ask_price, ask_size, bid_price, bid_size]
# Index: []

# %%
price_doge=response[0]
price_doge
# Out:
# {'symbol_id': 'HBDM_PERP_DOGE_USD',
#  'time_exchange': '2021-05-22T12:23:21.5853922Z',
#  'time_coinapi': '2021-05-22T12:23:21.5853922Z',
#  'ask_price': 0.352171,
#  'ask_size': 530.0,
#  'bid_price': 0.35217,
#  'bid_size': 1750.0}

# %%
btc_df=data_df[data_df['symbol_id']=='HBDM_FTS_BTC_USD_210528']
btc_df
# Out:
# Empty DataFrame
# Columns: [symbol_id, time_exchange, time_coinapi, ask_price, ask_size, bid_price, bid_size]
# Index: []

# %%
price_btc=response[30]

# %%
a_dic={'doge':price_doge,'btc':price_btc}
a_dic
# Out:
# {'doge': {'symbol_id': 'BTSE_SPOT_ATOM_TUSD',
#   'time_exchange': '2021-05-22T15:09:36.1418323Z',
#   'time_coinapi': '2021-05-22T15:09:36.1445485Z',
#   'ask_price': 12.997,
#   'ask_size': 360.7,
#   'bid_price': 12.65,
#   'bid_size': 927.1},
#  'btc': {'symbol_id': 'DRAGONEX_SPOT_DOGE_USDT',
#   'time_exchange': '2021-05-22T15:09:36.1626738Z',
#   'time_coinapi': '2021-05-22T15:09:36.1627880Z',
#   'ask_price': 0.355945,
#   'ask_size': 408.0,
#   'bid_price': 0.322642,
#   'bid_size': 36.0}}

# %%
crypto_df=pd.DataFrame(a_dic)
crypto_df
# Out:
#                                        doge                           btc
# symbol_id               BTSE_SPOT_ATOM_TUSD       DRAGONEX_SPOT_DOGE_USDT
# time_exchange  2021-05-22T15:09:36.1418323Z  2021-05-22T15:09:36.1626738Z
# time_coinapi   2021-05-22T15:09:36.1445485Z  2021-05-22T15:09:36.1627880Z
# ask_price                            12.997                      0.355945
# ask_size                              360.7                           408
# bid_price                             12.65                      0.322642
# bid_size                              927.1                            36

# %%
crypto_df.to_csv('./crypto_df.csv',index=False)

# %%
engine=sqlalchemy.create_engine('sqlite:///crypto_df',echo=True)
sqlite_connection=engine.connect()
# Out:
# 2021-05-22 10:16:29,778 INFO sqlalchemy.engine.base.Engine SELECT CAST('test plain returns' AS VARCHAR(60)) AS anon_1
# 2021-05-22 10:16:29,782 INFO sqlalchemy.engine.base.Engine ()
# 2021-05-22 10:16:29,784 INFO sqlalchemy.engine.base.Engine SELECT CAST('test unicode returns' AS VARCHAR(60)) AS anon_1
# 2021-05-22 10:16:29,785 INFO sqlalchemy.engine.base.Engine ()

# %%
sqlite_table="CryptoLife"
crypto_df.to_sql(sqlite_table, sqlite_connection, if_exists='fail')
# Out:
# 2021-05-22 10:19:13,161 INFO sqlalchemy.engine.base.Engine PRAGMA main.table_info("CryptoLife")
# 2021-05-22 10:19:13,162 INFO sqlalchemy.engine.base.Engine ()
# 2021-05-22 10:19:13,165 INFO sqlalchemy.engine.base.Engine PRAGMA temp.table_info("CryptoLife")
# 2021-05-22 10:19:13,166 INFO sqlalchemy.engine.base.Engine ()
# 2021-05-22 10:19:13,170 INFO sqlalchemy.engine.base.Engine
# CREATE TABLE "CryptoLife" (
# 	"index" TEXT,
# 	doge TEXT,
# 	btc TEXT
# )
#
#
# 2021-05-22 10:19:13,172 INFO sqlalchemy.engine.base.Engine ()
# 2021-05-22 10:19:13,179 INFO sqlalchemy.engine.base.Engine COMMIT
# 2021-05-22 10:19:13,181 INFO sqlalchemy.engine.base.Engine CREATE INDEX "ix_CryptoLife_index" ON "CryptoLife" ("index")
# 2021-05-22 10:19:13,182 INFO sqlalchemy.engine.base.Engine ()
# 2021-05-22 10:19:13,189 INFO sqlalchemy.engine.base.Engine COMMIT
# 2021-05-22 10:19:13,196 INFO sqlalchemy.engine.base.Engine BEGIN (implicit)
# 2021-05-22 10:19:13,199 INFO sqlalchemy.engine.base.Engine INSERT INTO "CryptoLife" ("index", doge, btc) VALUES (?, ?, ?)
# 2021-05-22 10:19:13,200 INFO sqlalchemy.engine.base.Engine (('symbol_id', 'BTSE_SPOT_ATOM_TUSD', 'DRAGONEX_SPOT_DOGE_USDT'), ('time_exchange', '2021-05-22T15:09:36.1418323Z', '2021-05-22T15:09:36.1626738Z'), ('time_coinapi', '2021-05-22T15:09:36.1445485Z', '2021-05-22T15:09:36.1627880Z'), ('ask_price', 12.997, 0.355945), ('ask_size', 360.7, 408.0), ('bid_price', 12.65, 0.322642), ('bid_size', 927.1, 36.0))
# 2021-05-22 10:19:13,203 INFO sqlalchemy.engine.base.Engine COMMIT
# 2021-05-22 10:19:13,299 INFO sqlalchemy.engine.base.Engine SELECT name FROM sqlite_master WHERE type='table' ORDER BY name
# 2021-05-22 10:19:13,302 INFO sqlalchemy.engine.base.Engine ()
