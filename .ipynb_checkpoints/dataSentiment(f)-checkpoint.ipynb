# %%
import pandas as pd
import os
import nltk
from nltk.corpus import stopwords

# %%
data_df=pd.read_csv("Data_project-3 - Sheet1.csv")
data_df
# Out:
#       Sentiment                                              title  \
# 0             2  Assuming to be true that Putin is manipulating...
# 1             0  My unpleasant experience from a Hillary suppor...
# 2             2  Given the recent findings about Trump illegall...
# 3             2  I'll be on Fox News Channel at 1pm (as a Dem S...
# 4             2  Russia is unashamedly Authoritarian, Christian...
# ...         ...                                                ...
# 1717          3  https://www.washingtonpost.com/video/politics/...
# 1718          3             Cruz loves trump &amp; hates democracy
# 1719          3                                  The Trump Project
# 1720          0    How would US political system handle Trump 2.0?
# 1721          0               Name one thing Trump has done wrong?
#
#       Unnamed: 2                 time
# 0              0  2016-12-30 23:21:38
# 1              1  2016-12-30 16:47:07
# 2              2  2016-12-30 14:50:26
# 3              3  2016-12-30 14:27:26
# 4              4  2016-12-30 14:14:00
# ...          ...                  ...
# 1717         671  2021-01-03 20:14:45
# 1718         672  2021-01-03 15:34:23
# 1719         673  2021-01-03 13:45:19
# 1720         675  2021-01-03 11:14:13
# 1721         676   2021-01-03 6:35:50
#
# [1722 rows x 4 columns]

# %%
data_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1722 entries, 0 to 1721
# Data columns (total 4 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Sentiment   1722 non-null   int64
#  1   title       1721 non-null   object
#  2   Unnamed: 2  1722 non-null   int64
#  3   time        1722 non-null   object
# dtypes: int64(2), object(2)
# memory usage: 53.9+ KB

# %%
hist = data_df.hist(bins=10)

# %%
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize
#!pip install WordCloud
from wordcloud import WordCloud
import matplotlib.pyplot as plt

# %%
STOPWORDS=["GOP","Sander","GOP party","Biden","support","would","Hillary","Clinton","year""would","could","Clinton","administration","vote","election","Donald","President","Trump","i", "me", "my", "myself", "we", "our", "ours", "ourselves", "you", "your", "yours", "yourself", "yourselves", "he", "him", "his", "himself", "she", "her", "hers", "herself", "it", "its", "itself", "they", "them", "their", "theirs", "themselves", "what", "which", "who", "whom", "this", "that", "these", "those", "am", "is", "are", "was", "were", "be", "been", "being", "have", "has", "had", "having", "do", "does", "did", "doing", "a", "an", "the", "and", "but", "if", "or", "because", "as", "until", "while", "of", "at", "by", "for", "with", "about", "against", "between", "into", "through", "during", "before", "after", "above", "below", "to", "from", "up", "down", "in", "out", "on", "off", "over", "under", "again", "further", "then", "once", "here", "there", "when", "where", "why", "how", "all", "any", "both", "each", "few", "more", "most", "other", "some", "such", "no", "nor", "not", "only", "own", "same", "so", "than", "too", "very", "s", "t", "can", "will", "just", "don", "should", "now"]

# %%
data_df=data_df.drop(1458)

# %%
# Create stopword list:
from nltk.corpus import stopwords

stopwords = set(STOPWORDS)
textt = " ".join(title for title in data_df["title"])
wordcloud = WordCloud(stopwords=stopwords).generate(textt)
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis("off")
plt.savefig('wordcloud11.png')
plt.show()

# %%
wordcloud.words_
# Out:
# {'think': 1.0,
#  'supporter': 0.9787234042553191,
#  'Republican': 0.925531914893617,
#  'people': 0.8085106382978723,
#  'U': 0.7872340425531915,
#  'Democrat': 0.6702127659574468,
#  'office': 0.6382978723404256,
#  'presidency': 0.6063829787234043,
#  'like': 0.5957446808510638,
#  'new': 0.5638297872340425,
#  'Obama': 0.5319148936170213,
#  'happen': 0.5212765957446809,
#  'political': 0.4787234042553192,
#  'win': 0.46808510638297873,
#  'State': 0.46808510638297873,
#  'impeached': 0.44680851063829785,
#  'Russia': 0.43617021276595747,
#  'get': 0.43617021276595747,
#  'actually': 0.425531914893617,
#  'make': 0.425531914893617,
#  'year': 0.4148936170212766,
#  'Secretary': 0.40425531914893614,
#  'one': 0.39361702127659576,
#  'party': 0.39361702127659576,
#  'say': 0.39361702127659576,
#  'right': 0.39361702127659576,
#  'good': 0.3829787234042553,
#  'likely': 0.3829787234042553,
#  'impeachment': 0.3829787234042553,
#  'much': 0.3723404255319149,
#  'future': 0.3723404255319149,
#  'Senate': 0.3723404255319149,
#  'chance': 0.3617021276595745,
#  'American': 0.35106382978723405,
#  'campaign': 0.35106382978723405,
#  'won': 0.35106382978723405,
#  'really': 0.35106382978723405,
#  'voter': 0.35106382978723405,
#  'term': 0.3404255319148936,
#  'pardon': 0.3191489361702128,
#  'change': 0.3191489361702128,
#  'elect': 0.30851063829787234,
#  'time': 0.30851063829787234,
#  'help': 0.30851063829787234,
#  'possible': 0.2978723404255319,
#  'bad': 0.2978723404255319,
#  'question': 0.2978723404255319,
#  'first': 0.2872340425531915,
#  'next': 0.2872340425531915,
#  'done': 0.2872340425531915,
#  'move': 0.2872340425531915,
#  'still': 0.2872340425531915,
#  'run': 0.2872340425531915,
#  'Twitter': 0.2872340425531915,
#  'power': 0.2765957446808511,
#  'way': 0.2765957446808511,
#  'House': 0.2765957446808511,
#  'want': 0.2765957446808511,
#  'amp': 0.26595744680851063,
#  'thing': 0.26595744680851063,
#  'China': 0.26595744680851063,
#  'mean': 0.26595744680851063,
#  'America': 0.26595744680851063,
#  'candidate': 0.2553191489361702,
#  'voted': 0.2553191489361702,
#  'going': 0.2553191489361702,
#  'day': 0.2553191489361702,
#  'take': 0.2553191489361702,
#  'job': 0.24468085106382978,
#  'since': 0.24468085106382978,
#  'go': 0.24468085106382978,
#  'back': 0.24468085106382978,
#  'Pence': 0.23404255319148937,
#  'stop': 0.23404255319148937,
#  'policies': 0.23404255319148937,
#  'many': 0.23404255319148937,
#  'made': 0.23404255319148937,
#  'Electoral College': 0.23404255319148937,
#  'left': 0.22340425531914893,
#  'presidential': 0.22340425531914893,
#  'see': 0.22340425531914893,
#  'opinion': 0.22340425531914893,
#  'believe': 0.22340425531914893,
#  'impeach': 0.22340425531914893,
#  'action': 0.22340425531914893,
#  'end': 0.2127659574468085,
#  'conservative': 0.2127659574468085,
#  'last': 0.2127659574468085,
#  'something': 0.2127659574468085,
#  'implication': 0.2127659574468085,
#  'Capitol': 0.2127659574468085,
#  'know': 0.20212765957446807,
#  'wall': 0.20212765957446807,
#  'law': 0.20212765957446807,
#  'Russian': 0.19148936170212766,
#  'effect': 0.19148936170212766,
#  'start': 0.19148936170212766,
#  'week': 0.19148936170212766,
#  'best': 0.19148936170212766,
#  'federal': 0.19148936170212766,
#  'thought': 0.19148936170212766,
#  'White House': 0.19148936170212766,
#  'media': 0.18085106382978725,
#  'Democratic': 0.18085106382978725,
#  'government': 0.18085106382978725,
#  'anyone': 0.18085106382978725,
#  'claim': 0.18085106382978725,
#  'lose': 0.18085106382978725,
#  'person': 0.18085106382978725,
#  'Putin': 0.1702127659574468,
#  'better': 0.1702127659574468,
#  'former': 0.1702127659574468,
#  'today': 0.1702127659574468,
#  'someone': 0.1702127659574468,
#  'post': 0.1702127659574468,
#  'inauguration': 0.1702127659574468,
#  'country': 0.1702127659574468,
#  'liberal': 0.1702127659574468,
#  'deal': 0.1702127659574468,
#  'Congress': 0.1702127659574468,
#  'become': 0.1702127659574468,
#  'elector': 0.1702127659574468,
#  'social media': 0.1702127659574468,
#  'recent': 0.1595744680851064,
#  'anti': 0.1595744680851064,
#  'policy': 0.1595744680851064,
#  'ever': 0.1595744680851064,
#  'seem': 0.1595744680851064,
#  'elections': 0.1595744680851064,
#  'find': 0.1595744680851064,
#  'affect': 0.1595744680851064,
#  "don't": 0.1595744680851064,
#  'v': 0.1595744680851064,
#  'Mueller': 0.1595744680851064,
#  'Republican Party': 0.1595744680851064,
#  'already': 0.14893617021276595,
#  'said': 0.14893617021276595,
#  'anything': 0.14893617021276595,
#  'expect': 0.14893617021276595,
#  'benefit': 0.14893617021276595,
#  'use': 0.14893617021276595,
#  'saying': 0.14893617021276595,
#  'impact': 0.14893617021276595,
#  'happened': 0.14893617021276595,
#  'feel': 0.14893617021276595,
#  'result': 0.14893617021276595,
#  'come': 0.14893617021276595,
#  'everyone': 0.14893617021276595,
#  'need': 0.14893617021276595,
#  'never': 0.14893617021276595,
#  'Democratic Party': 0.14893617021276595,
#  'possibly': 0.13829787234042554,
#  'potential': 0.13829787234042554,
#  'relations': 0.13829787234042554,
#  'evidence': 0.13829787234042554,
#  'military': 0.13829787234042554,
#  'amendment': 0.13829787234042554,
#  'agree': 0.13829787234042554,
#  'cause': 0.13829787234042554,
#  'plan': 0.13829787234042554,
#  'regard': 0.13829787234042554,
#  'understand': 0.13829787234042554,
#  'toward': 0.13829787234042554,
#  'even': 0.13829787234042554,
#  'enough': 0.13829787234042554,
#  'speech': 0.13829787234042554,
#  'United State': 0.13829787234042554,
#  'mind': 0.1276595744680851,
#  'given': 0.1276595744680851,
#  'team': 0.1276595744680851,
#  'history': 0.1276595744680851,
#  'idea': 0.1276595744680851,
#  'Serious': 0.1276595744680851,
#  'point': 0.1276595744680851,
#  'every': 0.1276595744680851,
#  'national': 0.1276595744680851,
#  'legal': 0.1276595744680851,
#  'business': 0.1276595744680851,
#  'current': 0.1276595744680851,
#  'issue': 0.1276595744680851,
#  'elected': 0.1276595744680851,
#  'votes': 0.1276595744680851,
#  'charge': 0.1276595744680851,
#  'getting': 0.1276595744680851,
#  'might': 0.1276595744680851,
#  'removed': 0.1276595744680851,
#  'name': 0.1276595744680851,
#  'case': 0.1276595744680851,
#  'USA': 0.1276595744680851,
#  'free': 0.1276595744680851,
#  'call': 0.1276595744680851,
#  "I'm": 0.1276595744680851,
#  'friend': 0.1276595744680851,
#  'lost': 0.1276595744680851,
#  'talk': 0.1276595744680851,
#  'event': 0.1276595744680851,
#  'another': 0.1276595744680851,
#  'guy': 0.1276595744680851,
#  'order': 0.11702127659574468,
#  'pro': 0.11702127659574468}

# %%
positive = data_df[data_df['Sentiment'] == 1]
negative = data_df[data_df['Sentiment'] == 2]
neutral= data_df[data_df['Sentiment'] == 0]
drop= data_df[data_df['Sentiment'] == 3]

# %%
stopwords = set(STOPWORDS)
pos= " ".join(title for title in positive.title)
wordcloud2 = WordCloud(stopwords=stopwords).generate(pos)

# %%
plt.imshow(wordcloud2, interpolation='bilinear')
plt.axis("off")
plt.show()

# %%
stopwords = set(STOPWORDS)
neg= " ".join(title for title in negative.title)
wordcloud3 = WordCloud(stopwords=stopwords).generate(neg)

# %%
plt.imshow(wordcloud3, interpolation='bilinear')
plt.axis("off")
plt.show()

# %%
sentiment_df=data_df.copy()

# %%
sentiment_df["Sentiment"]=sentiment_df['Sentiment'].replace({2 : 'negative'})
sentiment_df["Sentiment"]=sentiment_df['Sentiment'].replace({1 : 'positive'})
sentiment_df["Sentiment"]=sentiment_df['Sentiment'].replace({0 : 'neutral'})
sentiment_df["Sentiment"]=sentiment_df['Sentiment'].replace({3 : 'drop'})
sentiment_df
# Out:
#      Sentiment                                              title  Unnamed: 2  \
# 0     negative  Assuming to be true that Putin is manipulating...           0
# 1      neutral  My unpleasant experience from a Hillary suppor...           1
# 2     negative  Given the recent findings about Trump illegall...           2
# 3     negative  I'll be on Fox News Channel at 1pm (as a Dem S...           3
# 4     negative  Russia is unashamedly Authoritarian, Christian...           4
# ...        ...                                                ...         ...
# 1717      drop  https://www.washingtonpost.com/video/politics/...         671
# 1718      drop             Cruz loves trump &amp; hates democracy         672
# 1719      drop                                  The Trump Project         673
# 1720   neutral    How would US political system handle Trump 2.0?         675
# 1721   neutral               Name one thing Trump has done wrong?         676
#
#                      time
# 0     2016-12-30 23:21:38
# 1     2016-12-30 16:47:07
# 2     2016-12-30 14:50:26
# 3     2016-12-30 14:27:26
# 4     2016-12-30 14:14:00
# ...                   ...
# 1717  2021-01-03 20:14:45
# 1718  2021-01-03 15:34:23
# 1719  2021-01-03 13:45:19
# 1720  2021-01-03 11:14:13
# 1721   2021-01-03 6:35:50
#
# [1721 rows x 4 columns]

# %%
#!pip install plotly
import plotly.express as px
# Out:
# Requirement already satisfied: plotly in c:\users\fredd\anaconda3\lib\site-packages (5.1.0)
# Requirement already satisfied: tenacity>=6.2.0 in c:\users\fredd\anaconda3\lib\site-packages (from plotly) (7.0.0)
# Requirement already satisfied: six in c:\users\fredd\anaconda3\lib\site-packages (from plotly) (1.15.0)

# %%
sentiment_hist = sentiment_df['Sentiment'].hist(bins=10)
sentiment_hist
# Out:
# <AxesSubplot:>

# %%
from sklearn.model_selection import train_test_split
from nltk.tokenize import word_tokenize

# %%
#sentiment_df=sentiment_df.drop(['tokenized','leng'], axis=1)

# %%
from nltk.tokenize import TweetTokenizer
import pandas as pd
import nltk

# %%
sentiment_df['tokenize']=sentiment_df.apply(lambda row: nltk.word_tokenize(row['title']), axis=1)
word_tokens=sentiment_df['tokenize']
stop_words = STOPWORDS
for w in word_tokens:
    if w not in stop_words:
        filtered_sentence.append(w)
#sentiment_df=sentiment_df.drop("length", axis=1)
#sentiment_df=sentiment_df.append(filtered_sentence)
#print(filtered_sentence)
sentiment_df
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-37-ac7ea3c2edc3> in <module>
#       4 for w in word_tokens:
#       5     if w not in stop_words:
# ----> 6         filtered_sentence.append(w)
#       7 #sentiment_df=sentiment_df.drop("length", axis=1)
#       8 #sentiment_df=sentiment_df.append(filtered_sentence)
#
# NameError: name 'filtered_sentence' is not defined

# %%
example_sent = sentiment_df.apply(lambda row: row['title'], axis=1)
 
stop_words = STOPWORDS
 
word_tokens = word_tokenize(example_sent)
 
filtered_sentence = [w for w in word_tokens if not w.lower() in stop_words]
 
filtered_sentence = []
 
for w in word_tokens:
    if w not in stop_words:
        filtered_sentence.append(w)
 
print(word_tokens)
print(filtered_sentence)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-38-449088eae604> in <module>
#       3 stop_words = STOPWORDS
#       4
# ----> 5 word_tokens = word_tokenize(example_sent)
#       6
#       7 filtered_sentence = [w for w in word_tokens if not w.lower() in stop_words]
#
# ~\anaconda3\lib\site-packages\nltk\tokenize\__init__.py in word_tokenize(text, language, preserve_line)
#     127     :type preserve_line: bool
#     128     """
# --> 129     sentences = [text] if preserve_line else sent_tokenize(text, language)
#     130     return [
#     131         token for sent in sentences for token in _treebank_word_tokenizer.tokenize(sent)
#
# ~\anaconda3\lib\site-packages\nltk\tokenize\__init__.py in sent_tokenize(text, language)
#     105     """
#     106     tokenizer = load("tokenizers/punkt/{0}.pickle".format(language))
# --> 107     return tokenizer.tokenize(text)
#     108
#     109
#
# ~\anaconda3\lib\site-packages\nltk\tokenize\punkt.py in tokenize(self, text, realign_boundaries)
#    1270         Given a text, returns a list of the sentences in that text.
#    1271         """
# -> 1272         return list(self.sentences_from_text(text, realign_boundaries))
#    1273
#    1274     def debug_decisions(self, text):
#
# ~\anaconda3\lib\site-packages\nltk\tokenize\punkt.py in sentences_from_text(self, text, realign_boundaries)
#    1324         follows the period.
#    1325         """
# -> 1326         return [text[s:e] for s, e in self.span_tokenize(text, realign_boundaries)]
#    1327
#    1328     def _slices_from_text(self, text):
#
# ~\anaconda3\lib\site-packages\nltk\tokenize\punkt.py in <listcomp>(.0)
#    1324         follows the period.
#    1325         """
# -> 1326         return [text[s:e] for s, e in self.span_tokenize(text, realign_boundaries)]
#    1327
#    1328     def _slices_from_text(self, text):
#
# ~\anaconda3\lib\site-packages\nltk\tokenize\punkt.py in span_tokenize(self, text, realign_boundaries)
#    1314         if realign_boundaries:
#    1315             slices = self._realign_boundaries(text, slices)
# -> 1316         for sl in slices:
#    1317             yield (sl.start, sl.stop)
#    1318
#
# ~\anaconda3\lib\site-packages\nltk\tokenize\punkt.py in _realign_boundaries(self, text, slices)
#    1355         """
#    1356         realign = 0
# -> 1357         for sl1, sl2 in _pair_iter(slices):
#    1358             sl1 = slice(sl1.start + realign, sl1.stop)
#    1359             if not sl2:
#
# ~\anaconda3\lib\site-packages\nltk\tokenize\punkt.py in _pair_iter(it)
#     312     it = iter(it)
#     313     try:
# --> 314         prev = next(it)
#     315     except StopIteration:
#     316         return
#
# ~\anaconda3\lib\site-packages\nltk\tokenize\punkt.py in _slices_from_text(self, text)
#    1328     def _slices_from_text(self, text):
#    1329         last_break = 0
# -> 1330         for match in self._lang_vars.period_context_re().finditer(text):
#    1331             context = match.group() + match.group("after_tok")
#    1332             if self.text_contains_sentbreak(context):
#
# TypeError: expected string or bytes-like object
